# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time

# %%
df = pd.read_csv('/Users/galvanize/Documents/capstone2/DATA/listings.csv.gz')

# %%
df
# Out:
#             id                            listing_url       scrape_id  \
# 0        38585     https://www.airbnb.com/rooms/38585  20200529020107
# 1        80905     https://www.airbnb.com/rooms/80905  20200529020107
# 2       108061    https://www.airbnb.com/rooms/108061  20200529020107
# 3       155305    https://www.airbnb.com/rooms/155305  20200529020107
# 4       156805    https://www.airbnb.com/rooms/156805  20200529020107
# ...        ...                                    ...             ...
# 2382  43473737  https://www.airbnb.com/rooms/43473737  20200529020107
# 2383  43495845  https://www.airbnb.com/rooms/43495845  20200529020107
# 2384  43509635  https://www.airbnb.com/rooms/43509635  20200529020107
# 2385  43525648  https://www.airbnb.com/rooms/43525648  20200529020107
# 2386  43525848  https://www.airbnb.com/rooms/43525848  20200529020107
#
#      last_scraped                                               name  \
# 0      2020-06-04    Charming Victorian home - twin beds + breakfast
# 1      2020-06-04                                   French Chic Loft
# 2      2020-06-04  Walk to stores/parks/downtown. Fenced yard/Pet...
# 3      2020-05-29                 Cottage! BonPaul + Sharky's Hostel
# 4      2020-05-29                  Private Room "Ader" at BPS Hostel
# ...           ...                                                ...
# 2382   2020-06-04                                  Peace of Paradise
# 2383   2020-06-04  Luxury Downtown Asheville Condo with Mountain ...
# 2384   2020-06-04          Monthly furnished rental - Walk to town !
# 2385   2020-06-04  Close to Downtown, Secluded, Hot Tub, WiFi, Pe...
# 2386   2020-06-04                    Asheville campsite on the farm!
#
#                                                 summary  \
# 0     Per the City Council of Asheville. Due to the ...
# 1     Let yourself melt into the delectable décor of...
# 2     Walk to town in ten minutes! Monthly rental in...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2382  New construction apartment over detached garag...
# 2383  Stay in the center of Asheville. Walk to resta...
# 2384  MONTHLY Corporate or vacation home! This is a ...
# 2385  Location, Location, Fantastic Location!  2 Bed...
# 2386  This campsite is located on our 10 acre horse ...
#
#                                                   space  \
# 0     Charming room with 2 twin size beds, furnished...
# 1     Have you ever gazed at dreamy photos in a maga...
# 2     True Asheville...artist styled apartment with ...
# 3     Private cottage located behind the main house ...
# 4     Private Rooms at Bon Paul and Sharky's Hostel....
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384                                       Entire house
# 2385  This pet friendly log cabin is clean, cozy and...
# 2386  This is a tent site on the farm conveniently l...
#
#                                             description experiences_offered  \
# 0     Per the City Council of Asheville. Due to the ...                none
# 1     Let yourself melt into the delectable décor of...                none
# 2     Walk to town in ten minutes! Monthly rental in...                none
# 3     Private cottage located behind the main house ...                none
# 4     Private Rooms at Bon Paul and Sharky's Hostel....                none
# ...                                                 ...                 ...
# 2382  New construction apartment over detached garag...                none
# 2383  Stay in the center of Asheville. Walk to resta...                none
# 2384  MONTHLY Corporate or vacation home! This is a ...                none
# 2385  Location, Location, Fantastic Location!  2 Bed...                none
# 2386  This campsite is located on our 10 acre horse ...                none
#
#                                   neighborhood_overview  ... instant_bookable  \
# 0     Our North Asheville neighborhood stretches alo...  ...                f
# 1     Quiet, tucked away from the hustle and bustle ...  ...                t
# 2     I love my neighborhood! Its friendly, easy-goi...  ...                f
# 3     We are within easy walk of pubs, breweries, mu...  ...                t
# 4     Easy walk to pubs, cafes, bakery, breweries, l...  ...                t
# ...                                                 ...  ...              ...
# 2382                                                NaN  ...                f
# 2383                                                NaN  ...                t
# 2384  Off Charlotte street, you can walk to the Hist...  ...                t
# 2385                                                NaN  ...                t
# 2386  10 acre horse farm located just a few minutes ...  ...                t
#
#      is_business_travel_ready          cancellation_policy  \
# 0                           f                     moderate
# 1                           f              super_strict_60
# 2                           f  strict_14_with_grace_period
# 3                           f                     moderate
# 4                           f                     moderate
# ...                       ...                          ...
# 2382                        f                     moderate
# 2383                        f  strict_14_with_grace_period
# 2384                        f  strict_14_with_grace_period
# 2385                        f  strict_14_with_grace_period
# 2386                        f                     flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                t                                t
# 1                                f                                f
# 2                                f                                f
# 3                                f                                f
# 4                                f                                f
# ...                            ...                              ...
# 2382                             f                                f
# 2383                             f                                f
# 2384                             f                                f
# 2385                             f                                f
# 2386                             f                                f
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                 11
# 2                                  2
# 3                                  7
# 4                                  7
# ...                              ...
# 2382                               1
# 2383                               9
# 2384                               1
# 2385                               1
# 2386                              23
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                              11
# 2                                               2
# 3                                               1
# 4                                               1
# ...                                           ...
# 2382                                            1
# 2383                                            9
# 2384                                            1
# 2385                                            1
# 2386                                           23
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               2
# 4                                               2
# ...                                           ...
# 2382                                            0
# 2383                                            0
# 2384                                            0
# 2385                                            0
# 2386                                            0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               1.18
# 1                                               0               1.01
# 2                                               0               0.84
# 3                                               4               2.23
# 4                                               4               0.63
# ...                                           ...                ...
# 2382                                            0               4.00
# 2383                                            0                NaN
# 2384                                            0                NaN
# 2385                                            0                NaN
# 2386                                            0                NaN
#
# [2387 rows x 106 columns]

# %%
df_part1 = df.iloc[:,0:27]
df_part1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2387 non-null   int64
#  1   listing_url            2387 non-null   object
#  2   scrape_id              2387 non-null   int64
#  3   last_scraped           2387 non-null   object
#  4   name                   2387 non-null   object
#  5   summary                2373 non-null   object
#  6   space                  2108 non-null   object
#  7   description            2384 non-null   object
#  8   experiences_offered    2387 non-null   object
#  9   neighborhood_overview  1919 non-null   object
#  10  notes                  1428 non-null   object
#  11  transit                1739 non-null   object
#  12  access                 1718 non-null   object
#  13  interaction            1918 non-null   object
#  14  house_rules            1823 non-null   object
#  15  thumbnail_url          0 non-null      float64
#  16  medium_url             0 non-null      float64
#  17  picture_url            2387 non-null   object
#  18  xl_picture_url         0 non-null      float64
#  19  host_id                2387 non-null   int64
#  20  host_url               2387 non-null   object
#  21  host_name              2387 non-null   object
#  22  host_since             2387 non-null   object
#  23  host_location          2386 non-null   object
#  24  host_about             1682 non-null   object
#  25  host_response_time     2004 non-null   object
#  26  host_response_rate     2004 non-null   object
# dtypes: float64(3), int64(3), object(21)
# memory usage: 503.6+ KB

# %%
df_part1
# Out:
#             id                            listing_url       scrape_id  \
# 0        38585     https://www.airbnb.com/rooms/38585  20200529020107
# 1        80905     https://www.airbnb.com/rooms/80905  20200529020107
# 2       108061    https://www.airbnb.com/rooms/108061  20200529020107
# 3       155305    https://www.airbnb.com/rooms/155305  20200529020107
# 4       156805    https://www.airbnb.com/rooms/156805  20200529020107
# ...        ...                                    ...             ...
# 2382  43473737  https://www.airbnb.com/rooms/43473737  20200529020107
# 2383  43495845  https://www.airbnb.com/rooms/43495845  20200529020107
# 2384  43509635  https://www.airbnb.com/rooms/43509635  20200529020107
# 2385  43525648  https://www.airbnb.com/rooms/43525648  20200529020107
# 2386  43525848  https://www.airbnb.com/rooms/43525848  20200529020107
#
#      last_scraped                                               name  \
# 0      2020-06-04    Charming Victorian home - twin beds + breakfast
# 1      2020-06-04                                   French Chic Loft
# 2      2020-06-04  Walk to stores/parks/downtown. Fenced yard/Pet...
# 3      2020-05-29                 Cottage! BonPaul + Sharky's Hostel
# 4      2020-05-29                  Private Room "Ader" at BPS Hostel
# ...           ...                                                ...
# 2382   2020-06-04                                  Peace of Paradise
# 2383   2020-06-04  Luxury Downtown Asheville Condo with Mountain ...
# 2384   2020-06-04          Monthly furnished rental - Walk to town !
# 2385   2020-06-04  Close to Downtown, Secluded, Hot Tub, WiFi, Pe...
# 2386   2020-06-04                    Asheville campsite on the farm!
#
#                                                 summary  \
# 0     Per the City Council of Asheville. Due to the ...
# 1     Let yourself melt into the delectable décor of...
# 2     Walk to town in ten minutes! Monthly rental in...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2382  New construction apartment over detached garag...
# 2383  Stay in the center of Asheville. Walk to resta...
# 2384  MONTHLY Corporate or vacation home! This is a ...
# 2385  Location, Location, Fantastic Location!  2 Bed...
# 2386  This campsite is located on our 10 acre horse ...
#
#                                                   space  \
# 0     Charming room with 2 twin size beds, furnished...
# 1     Have you ever gazed at dreamy photos in a maga...
# 2     True Asheville...artist styled apartment with ...
# 3     Private cottage located behind the main house ...
# 4     Private Rooms at Bon Paul and Sharky's Hostel....
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384                                       Entire house
# 2385  This pet friendly log cabin is clean, cozy and...
# 2386  This is a tent site on the farm conveniently l...
#
#                                             description experiences_offered  \
# 0     Per the City Council of Asheville. Due to the ...                none
# 1     Let yourself melt into the delectable décor of...                none
# 2     Walk to town in ten minutes! Monthly rental in...                none
# 3     Private cottage located behind the main house ...                none
# 4     Private Rooms at Bon Paul and Sharky's Hostel....                none
# ...                                                 ...                 ...
# 2382  New construction apartment over detached garag...                none
# 2383  Stay in the center of Asheville. Walk to resta...                none
# 2384  MONTHLY Corporate or vacation home! This is a ...                none
# 2385  Location, Location, Fantastic Location!  2 Bed...                none
# 2386  This campsite is located on our 10 acre horse ...                none
#
#                                   neighborhood_overview  ...  \
# 0     Our North Asheville neighborhood stretches alo...  ...
# 1     Quiet, tucked away from the hustle and bustle ...  ...
# 2     I love my neighborhood! Its friendly, easy-goi...  ...
# 3     We are within easy walk of pubs, breweries, mu...  ...
# 4     Easy walk to pubs, cafes, bakery, breweries, l...  ...
# ...                                                 ...  ...
# 2382                                                NaN  ...
# 2383                                                NaN  ...
# 2384  Off Charlotte street, you can walk to the Hist...  ...
# 2385                                                NaN  ...
# 2386  10 acre horse farm located just a few minutes ...  ...
#
#                                             picture_url xl_picture_url  \
# 0     https://a0.muscache.com/im/pictures/216165/755...            NaN
# 1     https://a0.muscache.com/im/pictures/29807425/6...            NaN
# 2     https://z0.muscache.cn/im/pictures/41011975/0c...            NaN
# 3     https://a0.muscache.com/im/pictures/8880711/cf...            NaN
# 4     https://a0.muscache.com/im/pictures/23447d55-f...            NaN
# ...                                                 ...            ...
# 2382  https://a0.muscache.com/im/pictures/064579cf-c...            NaN
# 2383  https://a0.muscache.com/im/pictures/2c4465f8-b...            NaN
# 2384  https://a0.muscache.com/im/pictures/40026973-a...            NaN
# 2385  https://a0.muscache.com/im/pictures/14a26c33-9...            NaN
# 2386  https://a0.muscache.com/im/pictures/76132feb-7...            NaN
#
#         host_id                                     host_url        host_name  \
# 0        165529     https://www.airbnb.com/users/show/165529          Evelyne
# 1        427027     https://www.airbnb.com/users/show/427027          Celeste
# 2        320564     https://www.airbnb.com/users/show/320564             Lisa
# 3        746673     https://www.airbnb.com/users/show/746673          BonPaul
# 4        746673     https://www.airbnb.com/users/show/746673          BonPaul
# ...         ...                                          ...              ...
# 2382   43901986   https://www.airbnb.com/users/show/43901986          Bridget
# 2383  343440528  https://www.airbnb.com/users/show/343440528              Ben
# 2384  347052146  https://www.airbnb.com/users/show/347052146             Bird
# 2385    1767483    https://www.airbnb.com/users/show/1767483            Becky
# 2386    3665372    https://www.airbnb.com/users/show/3665372  Asheville Abode
#
#       host_since                              host_location  \
# 0     2010-07-13   Asheville, North Carolina, United States
# 1     2011-03-07   Asheville, North Carolina, United States
# 2     2010-12-16   Asheville, North Carolina, United States
# 3     2011-06-26   Asheville, North Carolina, United States
# 4     2011-06-26   Asheville, North Carolina, United States
# ...          ...                                        ...
# 2382  2015-09-10  Greenville, South Carolina, United States
# 2383  2020-04-08                                         US
# 2384  2020-05-21   Asheville, North Carolina, United States
# 2385  2012-02-17                                         US
# 2386  2012-09-24   Asheville, North Carolina, United States
#
#                                              host_about  host_response_time  \
# 0     (Hidden by Airbnb) Likes:\r\nDancing, Horse Ri...                 NaN
# 1     Locally-owned and operated Asheville Stay offe...      within an hour
# 2     I am a long time resident of Asheville and am ...      within an hour
# 3     We operate two traveler's hostels located in H...      within an hour
# 4     We operate two traveler's hostels located in H...      within an hour
# ...                                                 ...                 ...
# 2382  I moved to Asheville three years ago because I...      within an hour
# 2383                                                NaN      within an hour
# 2384                              Monthly rental only -                 NaN
# 2385                                                NaN      within an hour
# 2386  At Asheville Abode, guests come first. As prof...      within an hour
#
#       host_response_rate
# 0                    NaN
# 1                   100%
# 2                   100%
# 3                   100%
# 4                   100%
# ...                  ...
# 2382                100%
# 2383                 83%
# 2384                 NaN
# 2385                100%
# 2386                100%
#
# [2387 rows x 27 columns]

# %%
df_part1 = df_part1.drop(['listing_url', 'scrape_id', 'xl_picture_url','thumbnail_url','medium_url'], axis=1)

# %%
df_part1
# Out:
#             id last_scraped  \
# 0        38585   2020-06-04
# 1        80905   2020-06-04
# 2       108061   2020-06-04
# 3       155305   2020-05-29
# 4       156805   2020-05-29
# ...        ...          ...
# 2382  43473737   2020-06-04
# 2383  43495845   2020-06-04
# 2384  43509635   2020-06-04
# 2385  43525648   2020-06-04
# 2386  43525848   2020-06-04
#
#                                                    name  \
# 0       Charming Victorian home - twin beds + breakfast
# 1                                      French Chic Loft
# 2     Walk to stores/parks/downtown. Fenced yard/Pet...
# 3                    Cottage! BonPaul + Sharky's Hostel
# 4                     Private Room "Ader" at BPS Hostel
# ...                                                 ...
# 2382                                  Peace of Paradise
# 2383  Luxury Downtown Asheville Condo with Mountain ...
# 2384          Monthly furnished rental - Walk to town !
# 2385  Close to Downtown, Secluded, Hot Tub, WiFi, Pe...
# 2386                    Asheville campsite on the farm!
#
#                                                 summary  \
# 0     Per the City Council of Asheville. Due to the ...
# 1     Let yourself melt into the delectable décor of...
# 2     Walk to town in ten minutes! Monthly rental in...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2382  New construction apartment over detached garag...
# 2383  Stay in the center of Asheville. Walk to resta...
# 2384  MONTHLY Corporate or vacation home! This is a ...
# 2385  Location, Location, Fantastic Location!  2 Bed...
# 2386  This campsite is located on our 10 acre horse ...
#
#                                                   space  \
# 0     Charming room with 2 twin size beds, furnished...
# 1     Have you ever gazed at dreamy photos in a maga...
# 2     True Asheville...artist styled apartment with ...
# 3     Private cottage located behind the main house ...
# 4     Private Rooms at Bon Paul and Sharky's Hostel....
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384                                       Entire house
# 2385  This pet friendly log cabin is clean, cozy and...
# 2386  This is a tent site on the farm conveniently l...
#
#                                             description experiences_offered  \
# 0     Per the City Council of Asheville. Due to the ...                none
# 1     Let yourself melt into the delectable décor of...                none
# 2     Walk to town in ten minutes! Monthly rental in...                none
# 3     Private cottage located behind the main house ...                none
# 4     Private Rooms at Bon Paul and Sharky's Hostel....                none
# ...                                                 ...                 ...
# 2382  New construction apartment over detached garag...                none
# 2383  Stay in the center of Asheville. Walk to resta...                none
# 2384  MONTHLY Corporate or vacation home! This is a ...                none
# 2385  Location, Location, Fantastic Location!  2 Bed...                none
# 2386  This campsite is located on our 10 acre horse ...                none
#
#                                   neighborhood_overview  \
# 0     Our North Asheville neighborhood stretches alo...
# 1     Quiet, tucked away from the hustle and bustle ...
# 2     I love my neighborhood! Its friendly, easy-goi...
# 3     We are within easy walk of pubs, breweries, mu...
# 4     Easy walk to pubs, cafes, bakery, breweries, l...
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384  Off Charlotte street, you can walk to the Hist...
# 2385                                                NaN
# 2386  10 acre horse farm located just a few minutes ...
#
#                                                   notes  \
# 0     I can lend you a yoga mat or you can go to our...
# 1     there is Apple TV not cable TV (there is no op...
# 2                                                   NaN
# 3     Parking in our lot is limited. You can also pa...
# 4                                                   NaN
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384  Please note this is a minimum 30 day rental - ...
# 2385                                                NaN
# 2386  This is a functioning farm about 15 minutes to...
#
#                                                 transit  ...  \
# 0     You need a car, but UBER and Lyft are availabl...  ...
# 1     Park your car and walk anywhere and everywhere...  ...
# 2     You can walk and bike anywhere from here but i...  ...
# 3     There is a bus that picks up a block away that...  ...
# 4                The bus picks up one block away for $1  ...
# ...                                                 ...  ...
# 2382                                                NaN  ...
# 2383                                                NaN  ...
# 2384  10 minutes to the Biltmore Estate and many out...  ...
# 2385                                                NaN  ...
# 2386  It is strongly recommended to travel by car. T...  ...
#
#                                             house_rules  \
# 0     This list is based on previous experiences: * ...
# 1     THE GUEST WHO BOOKS AGREES TO: • Be present at...
# 2     This is a peaceful friendly neighborhood so, k...
# 3     7 day maximum stay.  Please no outside linens....
# 4     Guests must have ID, No Locals, No drugs, No L...
# ...                                                 ...
# 2382                                                NaN
# 2383                                                NaN
# 2384  This is a monthly rental  Not a short term wee...
# 2385      PLEASE NOTE: There is a one time $50 pet fee.
# 2386                                                NaN
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/im/pictures/216165/755...     165529
# 1     https://a0.muscache.com/im/pictures/29807425/6...     427027
# 2     https://z0.muscache.cn/im/pictures/41011975/0c...     320564
# 3     https://a0.muscache.com/im/pictures/8880711/cf...     746673
# 4     https://a0.muscache.com/im/pictures/23447d55-f...     746673
# ...                                                 ...        ...
# 2382  https://a0.muscache.com/im/pictures/064579cf-c...   43901986
# 2383  https://a0.muscache.com/im/pictures/2c4465f8-b...  343440528
# 2384  https://a0.muscache.com/im/pictures/40026973-a...  347052146
# 2385  https://a0.muscache.com/im/pictures/14a26c33-9...    1767483
# 2386  https://a0.muscache.com/im/pictures/76132feb-7...    3665372
#
#                                          host_url        host_name  \
# 0        https://www.airbnb.com/users/show/165529          Evelyne
# 1        https://www.airbnb.com/users/show/427027          Celeste
# 2        https://www.airbnb.com/users/show/320564             Lisa
# 3        https://www.airbnb.com/users/show/746673          BonPaul
# 4        https://www.airbnb.com/users/show/746673          BonPaul
# ...                                           ...              ...
# 2382   https://www.airbnb.com/users/show/43901986          Bridget
# 2383  https://www.airbnb.com/users/show/343440528              Ben
# 2384  https://www.airbnb.com/users/show/347052146             Bird
# 2385    https://www.airbnb.com/users/show/1767483            Becky
# 2386    https://www.airbnb.com/users/show/3665372  Asheville Abode
#
#       host_since                              host_location  \
# 0     2010-07-13   Asheville, North Carolina, United States
# 1     2011-03-07   Asheville, North Carolina, United States
# 2     2010-12-16   Asheville, North Carolina, United States
# 3     2011-06-26   Asheville, North Carolina, United States
# 4     2011-06-26   Asheville, North Carolina, United States
# ...          ...                                        ...
# 2382  2015-09-10  Greenville, South Carolina, United States
# 2383  2020-04-08                                         US
# 2384  2020-05-21   Asheville, North Carolina, United States
# 2385  2012-02-17                                         US
# 2386  2012-09-24   Asheville, North Carolina, United States
#
#                                              host_about host_response_time  \
# 0     (Hidden by Airbnb) Likes:\r\nDancing, Horse Ri...                NaN
# 1     Locally-owned and operated Asheville Stay offe...     within an hour
# 2     I am a long time resident of Asheville and am ...     within an hour
# 3     We operate two traveler's hostels located in H...     within an hour
# 4     We operate two traveler's hostels located in H...     within an hour
# ...                                                 ...                ...
# 2382  I moved to Asheville three years ago because I...     within an hour
# 2383                                                NaN     within an hour
# 2384                              Monthly rental only -                NaN
# 2385                                                NaN     within an hour
# 2386  At Asheville Abode, guests come first. As prof...     within an hour
#
#      host_response_rate
# 0                   NaN
# 1                  100%
# 2                  100%
# 3                  100%
# 4                  100%
# ...                 ...
# 2382               100%
# 2383                83%
# 2384                NaN
# 2385               100%
# 2386               100%
#
# [2387 rows x 22 columns]

# %%
hosts = df_part1[['host_id', 'host_name','host_location','host_since', 'host_about']]
hosts
# Out:
#         host_id        host_name                              host_location  \
# 0        165529          Evelyne   Asheville, North Carolina, United States
# 1        427027          Celeste   Asheville, North Carolina, United States
# 2        320564             Lisa   Asheville, North Carolina, United States
# 3        746673          BonPaul   Asheville, North Carolina, United States
# 4        746673          BonPaul   Asheville, North Carolina, United States
# ...         ...              ...                                        ...
# 2382   43901986          Bridget  Greenville, South Carolina, United States
# 2383  343440528              Ben                                         US
# 2384  347052146             Bird   Asheville, North Carolina, United States
# 2385    1767483            Becky                                         US
# 2386    3665372  Asheville Abode   Asheville, North Carolina, United States
#
#       host_since                                         host_about
# 0     2010-07-13  (Hidden by Airbnb) Likes:\r\nDancing, Horse Ri...
# 1     2011-03-07  Locally-owned and operated Asheville Stay offe...
# 2     2010-12-16  I am a long time resident of Asheville and am ...
# 3     2011-06-26  We operate two traveler's hostels located in H...
# 4     2011-06-26  We operate two traveler's hostels located in H...
# ...          ...                                                ...
# 2382  2015-09-10  I moved to Asheville three years ago because I...
# 2383  2020-04-08                                                NaN
# 2384  2020-05-21                              Monthly rental only -
# 2385  2012-02-17                                                NaN
# 2386  2012-09-24  At Asheville Abode, guests come first. As prof...
#
# [2387 rows x 5 columns]

# %%
type(hosts['host_since'])
hosts['host_since2'] = pd.to_datetime(hosts['host_since'], format= '%Y-%m-%d')
# #hosts['host_since'] = A
# #hosts['host_since']
# type(hosts['host_since'])
# Out:
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hosts['host_id'] =  hosts['host_id'].astype('str')
# Out:
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hosts = hosts.drop('host_since', axis=1)
hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_id        2387 non-null   object
#  1   host_name      2387 non-null   object
#  2   host_location  2386 non-null   object
#  3   host_about     1682 non-null   object
#  4   host_since2    2387 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 93.4+ KB

# %%
hosts['host_since'] =  hosts['host_since2']

hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_id        2387 non-null   object
#  1   host_name      2387 non-null   object
#  2   host_location  2386 non-null   object
#  3   host_about     1682 non-null   object
#  4   host_since2    2387 non-null   datetime64[ns]
#  5   host_since     2387 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(4)
# memory usage: 112.0+ KB

# %%
hosts = hosts.drop('host_since2', axis=1)
hosts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_id        2387 non-null   object
#  1   host_name      2387 non-null   object
#  2   host_location  2386 non-null   object
#  3   host_about     1682 non-null   object
#  4   host_since     2387 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 93.4+ KB

# %%
# listings_by_name = pd.DataFrame(hosts['host_name'].value_counts())

# listings_by_name.reset_index(inplace=True)


#listings_by_name.index

# %%
# listings_by_name.rename(columns={listings_by_name.index.name:'host_name'})
# listings_by_name

# %%
# listings_by_name.rename(columns={'host_name':'listings_count'},inplace=True)
# listings_by_name.rename(columns={'index':'host_name'}, inplace=True)

# %%
# listings_by_name

# %%
# listings_by_name.head(50)

# %%
listings_by_hostid = pd.DataFrame(hosts['host_id'].value_counts())
listings_by_hostid
# Out:
#            host_id
# 167186184       54
# 149601167       30
# 96187307        24
# 3665372         23
# 134903005       19
# ...            ...
# 36948751         1
# 20156554         1
# 94891912         1
# 103466318        1
# 146031082        1
#
# [1649 rows x 1 columns]

# %%
listings_by_hostid.reset_index(inplace=True)
listings_by_hostid
# Out:
#           index  host_id
# 0     167186184       54
# 1     149601167       30
# 2      96187307       24
# 3       3665372       23
# 4     134903005       19
# ...         ...      ...
# 1644   36948751        1
# 1645   20156554        1
# 1646   94891912        1
# 1647  103466318        1
# 1648  146031082        1
#
# [1649 rows x 2 columns]

# %%
listings_by_hostid.rename(columns={'host_id':'listings_count'}, inplace=True)

# %%
listings_by_hostid.rename(columns={'index':'host_id'}, inplace=True)
listings_by_hostid
# Out:
#         host_id  listings_count
# 0     167186184              54
# 1     149601167              30
# 2      96187307              24
# 3       3665372              23
# 4     134903005              19
# ...         ...             ...
# 1644   36948751               1
# 1645   20156554               1
# 1646   94891912               1
# 1647  103466318               1
# 1648  146031082               1
#
# [1649 rows x 2 columns]

# %%
top_100_hosters = listings_by_hostid.head(100)
bottom_100_hosters = listings_by_hostid.tail(100)
single_listing_hosters = np.where(listings_by_hostid['listings_count']==1)

# %%
top_100_hosters
#bottom_100_hosters
#single_listing_hosters
#single_listing_hosters.values_counts()
# Out:
#       host_id  listings_count
# 0   167186184              54
# 1   149601167              30
# 2    96187307              24
# 3     3665372              23
# 4   134903005              19
# ..        ...             ...
# 95    4709573               3
# 96   32670355               3
# 97   42676282               3
# 98  158275564               3
# 99  107027195               3
#
# [100 rows x 2 columns]

# %%
sns.distplot(listings_by_hostid, bins=25)
#sns.distplot(listings_by_name,bins=100, kde=False, norm_hist=True)

# %%
# titanic = sns.load_dataset("titanic")
# g = sns.catplot("alive", col="deck", col_wrap=4,
#                 data=titanic[titanic.deck.notnull()],
#                 kind="count", height=2.5, aspect=.8)

# %%
sns.distplot(top_100_hosters)

# %%
#sns.catplot('host_id', col='listings_count',  data=top_100_hosters[top_100_hosters.listings_count.notnull()], kind='count', height=2.5, aspect=.9)

# %%
#host_date = hosts['host_since']

plt.plot_date(x=hosts['host_since'], y=hosts['host_name'])
plt.show()

# %%
#host_date = hosts['host_since']
#sns.barplot(x='host_id', y='host_since', color='k', alpha=0.7, data=hosts)

# %%
hosts.sort_values('host_since', ascending=True)
# Out:
#         host_id host_name                             host_location  \
# 2315      47859     James  Charlotte, North Carolina, United States
# 587       62667   Heather  Asheville, North Carolina, United States
# 720       87397      Evan  Asheville, North Carolina, United States
# 1055      96130     Renee  Asheville, North Carolina, United States
# 212      106067   Heather  Asheville, North Carolina, United States
# ...         ...       ...                                       ...
# 2356  343440528       Ben                                        US
# 2383  343440528       Ben                                        US
# 2371  344807572   Richard                                        US
# 2379  345787487   Alladin                                        US
# 2384  347052146      Bird  Asheville, North Carolina, United States
#
#                                              host_about host_since
# 2315  Basic suburban dad.  2 kids, 2 dogs, 3 cats.  ... 2009-10-23
# 587   My husband and I love to travel and explore ne... 2009-12-13
# 720   I am a young(ish) environmental scientist and ... 2010-03-02
# 1055  I'm a former nomad now settled in Asheville, N... 2010-03-19
# 212   Hobbies: *hiking*, !food!, READING, ((((hospit... 2010-04-09
# ...                                                 ...        ...
# 2356                                                NaN 2020-04-08
# 2383                                                NaN 2020-04-08
# 2371                                                NaN 2020-04-27
# 2379                                                NaN 2020-05-09
# 2384                              Monthly rental only - 2020-05-21
#
# [2387 rows x 5 columns]

# %%
hosts['host_since'].max()
# Out:
# Timestamp('2020-05-21 00:00:00')

# %%
hosts['host_since'].min()
# Out:
# Timestamp('2009-10-23 00:00:00')
