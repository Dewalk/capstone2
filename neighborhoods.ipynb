# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time

# %%
df = pd.read_csv('/Users/galvanize/Documents/capstone2/DATA/listings.csv')

# %%
df
# Out:
#             id                                               name    host_id  \
# 0        38585    Charming Victorian home - twin beds + breakfast     165529
# 1        80905                                   French Chic Loft     427027
# 2       108061  Walk to stores/parks/downtown. Fenced yard/Pet...     320564
# 3       155305                 Cottage! BonPaul + Sharky's Hostel     746673
# 4       156805                  Private Room "Ader" at BPS Hostel     746673
# ...        ...                                                ...        ...
# 2382  43473737                                  Peace of Paradise   43901986
# 2383  43495845  Luxury Downtown Asheville Condo with Mountain ...  343440528
# 2384  43509635          Monthly furnished rental - Walk to town !  347052146
# 2385  43525648  Close to Downtown, Secluded, Hot Tub, WiFi, Pe...    1767483
# 2386  43525848                    Asheville campsite on the farm!    3665372
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2387 non-null   int64
#  1   name                            2387 non-null   object
#  2   host_id                         2387 non-null   int64
#  3   host_name                       2387 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   2387 non-null   int64
#  6   latitude                        2387 non-null   float64
#  7   longitude                       2387 non-null   float64
#  8   room_type                       2387 non-null   object
#  9   price                           2387 non-null   int64
#  10  minimum_nights                  2387 non-null   int64
#  11  number_of_reviews               2387 non-null   int64
# ...

# %%
neighborhoods_df = df[['id','host_id','neighbourhood','latitude','longitude','price','calculated_host_listings_count','availability_365']]

# %%
neighborhoods_df
# Out:
#             id    host_id  neighbourhood  latitude  longitude  price  \
# 0        38585     165529          28804  35.65146  -82.62792     50
# 1        80905     427027          28801  35.59779  -82.55540    765
# 2       108061     320564          28801  35.60670  -82.55563     75
# 3       155305     746673          28806  35.57864  -82.59578    107
# 4       156805     746673          28806  35.57864  -82.59578     71
# ...        ...        ...            ...       ...        ...    ...
# 2382  43473737   43901986          28805  35.59714  -82.46050     65
# 2383  43495845  343440528          28801  35.59451  -82.55317    305
# 2384  43509635  347052146          28801  35.60995  -82.55054    155
# 2385  43525648    1767483          28803  35.49753  -82.50975    225
# 2386  43525848    3665372          28806  35.63243  -82.62861     19
#
#       calculated_host_listings_count  availability_365
# 0                                  1                 2
# ...

# %%
neighborhoods_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2387 non-null   int64
#  1   host_id                         2387 non-null   int64
#  2   neighbourhood                   2387 non-null   int64
#  3   latitude                        2387 non-null   float64
#  4   longitude                       2387 non-null   float64
#  5   price                           2387 non-null   int64
#  6   calculated_host_listings_count  2387 non-null   int64
#  7   availability_365                2387 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 149.3 KB

# %%
#WHY 'SETTINGWITHCOPYWARNING' WHEN I DO THIS??
# neighborhoods_df['host_id'] =  neighborhoods_df['host_id'].astype('str')
# neighborhoods_df['id'] =  neighborhoods_df['id'].astype('str')
# neighborhoods_df['neighbourhood'] =  neighborhoods_df['neighbourhood'].astype('str')

# %%
neighborhoods_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2387 non-null   object
#  1   host_id                         2387 non-null   object
#  2   neighbourhood                   2387 non-null   object
#  3   latitude                        2387 non-null   float64
#  4   longitude                       2387 non-null   float64
#  5   price                           2387 non-null   int64
#  6   calculated_host_listings_count  2387 non-null   int64
#  7   availability_365                2387 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 149.3+ KB

# %%
# neighborhoods_df.to_csv(r'neighborhoods.csv')
